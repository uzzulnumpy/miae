# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# %%
s = Service('../driver/chromedriver')
driver = webdriver.Chrome(service=s)
driver.get("https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com")

# %%
driver.save_screenshot('../images/001.png')
# Out:
# True

# %%
elem_login = driver.find_element_by_id("id")
elem_login.clear()
elem_login.send_keys("bamxdam")

elem_login = driver.find_element_by_id("pw")
elem_login.clear()
elem_login.send_keys("aldofvm803!")

xpath = ("""//*[@id="log.login"]/span""")
driver.find_element_by_xpath(xpath).click()
# Out:
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\3445324427.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem_login = driver.find_element_by_id("id")
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\3445324427.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem_login = driver.find_element_by_id("pw")
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\3445324427.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(xpath).click()

# %%
driver.get("http://mail.naver.com")

# %%
from bs4 import BeautifulSoup

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
raw_list = soup.find_all('div', 'name _ccr(lst.from)')
raw_list
# Out:
# [<div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31643) _stopDefault" href="#" title='"예스24(콕편지) " &lt;no-reply@yes24.com&gt;'>예스24(콕편지) </a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31642) _stopDefault" href="#" title='"티몬 밸런스딜" &lt;noreply@tmon.kr&gt;'>티몬 밸런스딜</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31641) _stopDefault" href="#" title='"Namepr" &lt;namepr@namepr.net&gt;'>Namepr</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31640) _stopDefault" href="#" title='"Namepr" &lt;namepr@namepr.co.kr&gt;'>Namepr</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31639) _stopDefault" href="#" title='"따뜻한하루" &lt;good@onday.or.kr&gt;'>따뜻한하루</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31638) _stopDefault" href="#" title='"티몬 10분어택" &lt;noreply@tmon.kr&gt;'>티몬 10분어택</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31637) _stopDefault" href="#" title='"티몬 단하루" &lt;noreply@tmon.kr&gt;'>티몬 단하루</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31636) _stopDefault" href="#" title='"예스24(콩편지)" &lt;no-reply@yes24.com&gt;'>예스24(콩편지)</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31635) _stopDefault" href="#" title='"티몬 맘&amp;베이비위크" &lt;noreply@tmon.kr&gt;'>티몬 맘&amp;베이비위크</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31634) _stopDefault" href="#" title='"한국발명진흥회" &lt;kipa2010@kipa.org&gt;'>한국발명진흥회</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31633) _stopDefault" href="#" title='"티몬" &lt;noreply@tmon.kr&gt;'>티몬</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31632) _stopDefault" href="#" title='"따뜻한하루" &lt;good@onday.or.kr&gt;'>따뜻한하루</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31631) _stopDefault" href="#" title='"Namepr" &lt;namepr@namepr.co.kr&gt;'>Namepr</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31630) _stopDefault" href="#" title='"티몬 밸런스딜" &lt;noreply@tmon.kr&gt;'>티몬 밸런스딜</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|31629) _stopDefault" href="#" title='"Namepr" &lt;namepr@namepr.net&gt;'>Namepr</a></div>]

# %%
send_list = [raw_list[n].find('a').get_text() for n in range(0, len(raw_list))]
send_list
# Out:
# ['예스24(콕편지) ',
#  '티몬 밸런스딜',
#  'Namepr',
#  'Namepr',
#  '따뜻한하루',
#  '티몬 10분어택',
#  '티몬 단하루',
#  '예스24(콩편지)',
#  '티몬 맘&베이비위크',
#  '한국발명진흥회',
#  '티몬',
#  '따뜻한하루',
#  'Namepr',
#  '티몬 밸런스딜',
#  'Namepr']

# %%
driver.close()

# %%
## 4-2 서울시 구별 주유소 가격 정보 얻기

# %%
s = Service('../driver/chromedriver')
driver = webdriver.Chrome(service=s)
driver.get("http://www.opinet.co.kr/searRgSelect.do")
driver.get("http://www.opinet.co.kr/searRgSelect.do")

# %%
gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list = gu_list_raw.find_elements_by_tag_name("option")
# Out:
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\3064256868.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")

# %%
gu_names = [option.get_attribute("value") for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
element = driver.find_element_by_id("SIGUNGU_NM0")
element.send_keys(gu_names[0])
# Out:
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\2813951130.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element = driver.find_element_by_id("SIGUNGU_NM0")

# %%
xpath = """//*[@id="searRgSelect"]"""
element_sel_gu = driver.find_element_by_xpath(xpath).click()
# Out:
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\2799069171.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element_sel_gu = driver.find_element_by_xpath(xpath).click()

# %%
xpath = """//*[@id="glopopd_excel"]"""
element_get_excel = driver.find_element_by_xpath(xpath).click()
# Out:
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\2347221567.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element_get_excel = driver.find_element_by_xpath(xpath).click()

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (7.6.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (5.1.3)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\bamxd\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (8.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets) (6.7.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.1)
# Requirement already satisfied: nest-asyncio in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.4)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: pygments in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.24)
# Requirement already satisfied: backcall in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.1.4)
# Requirement already satisfied: black in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (21.12b0)
# Requirement already satisfied: decorator in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (58.1.0)
# Requirement already satisfied: pickleshare in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: colorama in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: entrypoints in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (303)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: wcwidth in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.7)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: nbconvert in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.4.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.1)
# Requirement already satisfied: prometheus-client in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.0)
# Requirement already satisfied: jinja2 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: argon2-cffi in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: platformdirs>=2 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (2.4.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (4.0.1)
# Requirement already satisfied: tomli<2.0.0,>=0.2.6 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (1.2.3)
# Requirement already satisfied: pathspec<1,>=0.9.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (0.9.0)
# Requirement already satisfied: click>=7.1.2 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.10)
# Requirement already satisfied: testpath in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: bleach in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: webencodings in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.6)
# Requirement already satisfied: asttokens in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: executing in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.2)
# Requirement already satisfied: pure-eval in c:\users\bamxd\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.1)

# %%
import time
#tqdm 안쓰고 하기
for gu in gu_names:
    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu)

    time.sleep(2)

    xpath = """//*[@id="searRgSelect"]"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()

    time.sleep(1)

    xpath = """//*[@id="glopopd_excel"]"""
    element_get_excel = driver.find_element_by_xpath(xpath).click()

    time.sleep(1)
# Out:
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\2189709386.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element = driver.find_element_by_id("SIGUNGU_NM0")
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\2189709386.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element_sel_gu = driver.find_element_by_xpath(xpath).click()
# C:\Users\bamxd\AppData\Local\Temp\ipykernel_3740\2189709386.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element_get_excel = driver.find_element_by_xpath(xpath).click()

# %%
driver.close()

# %%
## 4-5. 구별 주유 가격에 대한 데이터의 정리

# %%
import pandas as pd
from glob import glob

# %%
glob('../data/지역_위치별(주유소)*.xls')
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (18).xls',
#  '../data\\지역_위치별(주유소) (19).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (20).xls',
#  '../data\\지역_위치별(주유소) (21).xls',
#  '../data\\지역_위치별(주유소) (22).xls',
#  '../data\\지역_위치별(주유소) (23).xls',
#  '../data\\지역_위치별(주유소) (24).xls',
#  '../data\\지역_위치별(주유소) (25).xls',
#  '../data\\지역_위치별(주유소) (26).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls']

# %%
stations_files = glob('../data/지역_위치별(주유소)*.xls')
stations_files
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (18).xls',
#  '../data\\지역_위치별(주유소) (19).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (20).xls',
#  '../data\\지역_위치별(주유소) (21).xls',
#  '../data\\지역_위치별(주유소) (22).xls',
#  '../data\\지역_위치별(주유소) (23).xls',
#  '../data\\지역_위치별(주유소) (24).xls',
#  '../data\\지역_위치별(주유소) (25).xls',
#  '../data\\지역_위치별(주유소) (26).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls']

# %%
tmp_raw = []

for file_name in stations_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
    
station_raw = pd.concat(tmp_raw)

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 507 entries, 0 to 10
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      507 non-null    object
#  1   상호      507 non-null    object
#  2   주소      507 non-null    object
#  3   상표      507 non-null    object
#  4   전화번호    507 non-null    object
#  5   셀프여부    507 non-null    object
#  6   고급휘발유   507 non-null    object
#  7   휘발유     507 non-null    object
#  8   경유      507 non-null    object
#  9   실내등유    507 non-null    object
# dtypes: object(10)
# memory usage: 43.6+ KB

# %%
station_raw.head()
# Out:
#       지역                   상호                      주소      상표          전화번호  \
# 0  서울특별시          (주)보성 세곡주유소   서울 강남구  헌릉로 731 (세곡동)   SK에너지   02-445-6870
# 1  서울특별시                방죽주유소   서울 강남구 밤고개로 215 (율현동)   GS칼텍스   02-459-3434
# 2  서울특별시  현대오일뱅크(주)직영 산성셀프주유소          서울 강남구 헌릉로 730  현대오일뱅크  02-2226-4963
# 3  서울특별시              자곡셀프주유소   서울 강남구 밤고개로 120 (자곡동)   SK에너지   02-445-5841
# 4  서울특별시                일원주유소  서울 강남구 양재대로55길 3 (일원동)   S-OIL  02-2226-5188
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    Y     -  1993  1940     -
# 1    Y     -  1997  1949     -
# 2    Y  2140  2000  1950     -
# 3    Y     -  2038  1981     -
# 4    Y     -  2038  1981  1600

# %%
stations = pd.DataFrame({'Oil_store':station_raw['상호'], 
                                       '주소':station_raw['주소'],
                                       '가격':station_raw['휘발유'],
                                       '셀프':station_raw['셀프여부'],
                                       '상표':station_raw['상표']  })
stations.head()
# Out:
#              Oil_store                      주소    가격 셀프      상표
# 0          (주)보성 세곡주유소   서울 강남구  헌릉로 731 (세곡동)  1993  Y   SK에너지
# 1                방죽주유소   서울 강남구 밤고개로 215 (율현동)  1997  Y   GS칼텍스
# 2  현대오일뱅크(주)직영 산성셀프주유소          서울 강남구 헌릉로 730  2000  Y  현대오일뱅크
# 3              자곡셀프주유소   서울 강남구 밤고개로 120 (자곡동)  2038  Y   SK에너지
# 4                일원주유소  서울 강남구 양재대로55길 3 (일원동)  2038  Y   S-OIL

# %%
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# Out:
#              Oil_store                      주소    가격 셀프      상표    구
# 0          (주)보성 세곡주유소   서울 강남구  헌릉로 731 (세곡동)  1993  Y   SK에너지  강남구
# 1                방죽주유소   서울 강남구 밤고개로 215 (율현동)  1997  Y   GS칼텍스  강남구
# 2  현대오일뱅크(주)직영 산성셀프주유소          서울 강남구 헌릉로 730  2000  Y  현대오일뱅크  강남구
# 3              자곡셀프주유소   서울 강남구 밤고개로 120 (자곡동)  2038  Y   SK에너지  강남구
# 4                일원주유소  서울 강남구 양재대로55길 3 (일원동)  2038  Y   S-OIL  강남구

# %%
stations['구'].unique()
# Out:
# array(['강남구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구',
#        '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구',
#        '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구'], dtype=object)

# %%
stations[stations['구']=='서울특별시']
# Out:
# Empty DataFrame
# Columns: [Oil_store, 주소, 가격, 셀프, 상표, 구]
# Index: []

# %%
stations.loc[stations['구']=='서울특별시', '구'] = '성동구'
stations['구'].unique()
# Out:
# array(['강남구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구',
#        '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구',
#        '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구'], dtype=object)

# %%
stations[stations['구']=='특별시']
# Out:
# Empty DataFrame
# Columns: [Oil_store, 주소, 가격, 셀프, 상표, 구]
# Index: []

# %%
stations.loc[stations['구']=='특별시', '구'] = '도봉구'
stations['구'].unique()
# Out:
# array(['강남구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구',
#        '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구',
#        '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구'], dtype=object)

# %%
stations[stations['가격']=='-']
# Out:
#           Oil_store                         주소 가격 셀프      상표     구
# 34            삼성주유소       서울 강남구 삼성로 521 (삼성동)  -  N   SK에너지   강남구
# 35            경원주유소      서울 강남구 도산대로 428 (청담동)  -  N   S-OIL   강남구
# 36            동우주유소  서울특별시 강남구  봉은사로 311 (논현동)  -  N   SK에너지   강남구
# 17         정다운셀프주유소             서울 도봉구 도봉로 635  -  Y   SK에너지   도봉구
# 34            경원주유소      서울 강남구 도산대로 428 (청담동)  -  N   S-OIL   강남구
# 35            삼성주유소       서울 강남구 삼성로 521 (삼성동)  -  N   SK에너지   강남구
# 36            동우주유소  서울특별시 강남구  봉은사로 311 (논현동)  -  N   SK에너지   강남구
# 27    지에스칼텍스㈜ 화일주유소            서울 영등포구 도림로 415  -  Y   GS칼텍스  영등포구
# 12            서계주유소   서울특별시 용산구  청파로 367 (청파동)  -  N   GS칼텍스   용산구
# 16            삼융주유소       서울 은평구 수색로 299 (수색동)  -  N   SK에너지   은평구
# 8   현대오일뱅크㈜직영 재동주유소        서울 종로구 율곡로 58 (경운동)  -  N  현대오일뱅크   종로구
# 10  지에스칼텍스(주)직영 역전점               서울 중구 퇴계로 15  -  N   GS칼텍스    중구
# 15          구의스타주유소             서울 광진구 자양로 103  -  N   GS칼텍스   광진구

# %%
stations = stations[stations['가격'] != '-']
stations.head()
# Out:
#              Oil_store                      주소    가격 셀프      상표    구
# 0          (주)보성 세곡주유소   서울 강남구  헌릉로 731 (세곡동)  1993  Y   SK에너지  강남구
# 1                방죽주유소   서울 강남구 밤고개로 215 (율현동)  1997  Y   GS칼텍스  강남구
# 2  현대오일뱅크(주)직영 산성셀프주유소          서울 강남구 헌릉로 730  2000  Y  현대오일뱅크  강남구
# 3              자곡셀프주유소   서울 강남구 밤고개로 120 (자곡동)  2038  Y   SK에너지  강남구
# 4                일원주유소  서울 강남구 양재대로55길 3 (일원동)  2038  Y   S-OIL  강남구

# %%
stations['가격'] = [float(value) for value in stations['가격']]

# %%
stations.reset_index(inplace=True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Oil_store  494 non-null    object
#  1   주소         494 non-null    object
#  2   가격         494 non-null    float64
#  3   셀프         494 non-null    object
#  4   상표         494 non-null    object
#  5   구          494 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 23.3+ KB

# %%
stations.head()
# Out:
#              Oil_store                      주소      가격 셀프      상표    구
# 0          (주)보성 세곡주유소   서울 강남구  헌릉로 731 (세곡동)  1993.0  Y   SK에너지  강남구
# 1                방죽주유소   서울 강남구 밤고개로 215 (율현동)  1997.0  Y   GS칼텍스  강남구
# 2  현대오일뱅크(주)직영 산성셀프주유소          서울 강남구 헌릉로 730  2000.0  Y  현대오일뱅크  강남구
# 3              자곡셀프주유소   서울 강남구 밤고개로 120 (자곡동)  2038.0  Y   SK에너지  강남구
# 4                일원주유소  서울 강남구 양재대로55길 3 (일원동)  2038.0  Y   S-OIL  강남구

# %%
## 4-4 셀프 주유소는 정말 저렴한지 boxplot으로 확인하기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x000001FB5BC9C700>
# Traceback (most recent call last):
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\std.py", line 1147, in __del__
#     self.close()
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\notebook.py", line 286, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x000001FB5BC9C700>
# Traceback (most recent call last):
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\std.py", line 1147, in __del__
#     self.close()
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\notebook.py", line 286, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x000001FB5BC9C700>
# Traceback (most recent call last):
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\std.py", line 1147, in __del__
#     self.close()
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\notebook.py", line 286, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x000001FB5BC9C700>
# Traceback (most recent call last):
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\std.py", line 1147, in __del__
#     self.close()
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\notebook.py", line 286, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x000001FB5BC9C700>
# Traceback (most recent call last):
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\std.py", line 1147, in __del__
#     self.close()
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\notebook.py", line 286, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x000001FB5BC9C700>
# Traceback (most recent call last):
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\std.py", line 1147, in __del__
#     self.close()
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\notebook.py", line 286, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x000001FB5BC9C700>
# Traceback (most recent call last):
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\std.py", line 1147, in __del__
#     self.close()
#   File "C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\notebook.py", line 286, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'

# %%
stations.boxplot(column='가격', by='셀프', figsize=(12,8));

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", hue="셀프", data=stations, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", data=stations, palette="Set3")
sns.swarmplot(x="상표", y="가격", data=stations, color=".6")
plt.show()
# Out:
# C:\Users\bamxd\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
stations.sort_values(by='가격', ascending=False).head(10)
# Out:
#            Oil_store                       주소      가격 셀프      상표    구
# 359            서남주유소             서울 중구 통일로 30  2829.0  N   SK에너지   중구
# 358  SK에너지(주) 퇴계로주유소     서울 중구 퇴계로 228 (필동2가)  2654.0  N   SK에너지   중구
# 325           동자동주유소  서울 용산구 한강대로104길 6 (동자동)  2590.0  N   SK에너지  용산구
# 261          제이제이주유소           서울 강남구 언주로 716  2545.0  N  현대오일뱅크  강남구
# 33           제이제이주유소           서울 강남구 언주로 716  2545.0  N  현대오일뱅크  강남구
# 324            한석주유소           서울 용산구 이촌로 164  2531.0  N   SK에너지  용산구
# 357            필동주유소    서울 중구  퇴계로 196 (필동2가)  2519.0  N   GS칼텍스   중구
# 260         (주)만정에너지    서울 강남구 봉은사로 433 (삼성동)  2498.0  N   GS칼텍스  강남구
# 32          (주)만정에너지    서울 강남구 봉은사로 433 (삼성동)  2498.0  N   GS칼텍스  강남구
# 356            약수주유소            서울 중구 다산로 173  2483.0  N   GS칼텍스   중구

# %%
stations.sort_values(by='가격', ascending=True).head(10)
# Out:
#           Oil_store                         주소      가격 셀프     상표    구
# 34            한신주유소      서울 노원구 동일로 1089 (공릉동)  1968.0  Y  SK에너지  노원구
# 196          아시아주유소       서울 송파구 도곡로 438 (잠실동)  1978.0  Y  GS칼텍스  송파구
# 122          신반포주유소       서울 서초구 사평대로 94 (반포동)  1978.0  N  SK에너지  서초구
# 264           현대주유소     서울 양천구 남부순환로 372 (신월동)  1979.0  Y  S-OIL  양천구
# 262           신월주유소       서울 양천구 신월로 193 (신월동)  1979.0  Y  GS칼텍스  양천구
# 263  (주)타이거오일 신정주유소       서울 양천구 중앙로 226 (신정동)  1979.0  Y  SK에너지  양천구
# 265   지에스칼텍스㈜ 서호주유소           서울 양천구 남부순환로 317  1980.0  Y  GS칼텍스  양천구
# 401           방화주유소     서울 강서구 방화동로 58-2 (방화동)  1983.0  N  SK에너지  강서구
# 266          양천구주유소       서울 양천구 국회대로 275 (목동)  1985.0  Y  알뜰주유소  양천구
# 483           구광주유소  서울특별시 금천구  서부샛길 674 (가산동)  1985.0  N  S-OIL  금천구

# %%
import numpy as np

gu_data = pd.pivot_table(stations, index=["구"], values=["가격"], 
                         aggfunc=np.mean)
gu_data.head()
# Out:
#               가격
# 구
# 강남구  2173.647059
# 강동구  2088.428571
# 강북구  2030.153846
# 강서구  2052.031250
# 관악구  2055.714286

# %%
geo_path = '../data/02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, 
                 tiles='Stamen Toner')

map.choropleth(geo_data = geo_str,
               data = gu_data,
               columns=[gu_data.index, '가격'],
               fill_color='PuRd', #PuRd, YlGnBu
               key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_45a35592d60948bcb8c0d6f9eeca66fc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_45a35592d60948bcb8c0d6f9eeca66fc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_45a35592d60948bcb8c0d6f9eeca66fc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_45a35592d60948bcb8c0d6f9eeca66fc%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
## 4-6 서울시 주유 가격 상하위 10개 주유소 지도에 표기하기

# %%
oil_price_top10 = stations.sort_values(by='가격', ascending=False).head(10)
oil_price_top10
# Out:
#            Oil_store                       주소      가격 셀프      상표    구
# 359            서남주유소             서울 중구 통일로 30  2829.0  N   SK에너지   중구
# 358  SK에너지(주) 퇴계로주유소     서울 중구 퇴계로 228 (필동2가)  2654.0  N   SK에너지   중구
# 325           동자동주유소  서울 용산구 한강대로104길 6 (동자동)  2590.0  N   SK에너지  용산구
# 261          제이제이주유소           서울 강남구 언주로 716  2545.0  N  현대오일뱅크  강남구
# 33           제이제이주유소           서울 강남구 언주로 716  2545.0  N  현대오일뱅크  강남구
# 324            한석주유소           서울 용산구 이촌로 164  2531.0  N   SK에너지  용산구
# 357            필동주유소    서울 중구  퇴계로 196 (필동2가)  2519.0  N   GS칼텍스   중구
# 260         (주)만정에너지    서울 강남구 봉은사로 433 (삼성동)  2498.0  N   GS칼텍스  강남구
# 32          (주)만정에너지    서울 강남구 봉은사로 433 (삼성동)  2498.0  N   GS칼텍스  강남구
# 356            약수주유소            서울 중구 다산로 173  2483.0  N   GS칼텍스   중구

# %%
oil_price_bottom10 = stations.sort_values(by='가격', ascending=True).head(10)
oil_price_bottom10
# Out:
#           Oil_store                         주소      가격 셀프     상표    구
# 34            한신주유소      서울 노원구 동일로 1089 (공릉동)  1968.0  Y  SK에너지  노원구
# 196          아시아주유소       서울 송파구 도곡로 438 (잠실동)  1978.0  Y  GS칼텍스  송파구
# 122          신반포주유소       서울 서초구 사평대로 94 (반포동)  1978.0  N  SK에너지  서초구
# 264           현대주유소     서울 양천구 남부순환로 372 (신월동)  1979.0  Y  S-OIL  양천구
# 262           신월주유소       서울 양천구 신월로 193 (신월동)  1979.0  Y  GS칼텍스  양천구
# 263  (주)타이거오일 신정주유소       서울 양천구 중앙로 226 (신정동)  1979.0  Y  SK에너지  양천구
# 265   지에스칼텍스㈜ 서호주유소           서울 양천구 남부순환로 317  1980.0  Y  GS칼텍스  양천구
# 401           방화주유소     서울 강서구 방화동로 58-2 (방화동)  1983.0  N  SK에너지  강서구
# 266          양천구주유소       서울 양천구 국회대로 275 (목동)  1985.0  Y  알뜰주유소  양천구
# 483           구광주유소  서울특별시 금천구  서부샛길 674 (가산동)  1985.0  N  S-OIL  금천구

# %%
gmap_key = "#" # 2장에서 구한 자신의 key를 입력
gmaps = googlemaps.Client(key=gmap_key)

# %%
from tqdm import tqdm

lat = []
lng = []

for n in tqdm(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# 100%|██████████| 10/10 [00:01<00:00,  6.88it/s]
#            Oil_store                       주소      가격 셀프      상표    구  \
# 359            서남주유소             서울 중구 통일로 30  2829.0  N   SK에너지   중구
# 358  SK에너지(주) 퇴계로주유소     서울 중구 퇴계로 228 (필동2가)  2654.0  N   SK에너지   중구
# 325           동자동주유소  서울 용산구 한강대로104길 6 (동자동)  2590.0  N   SK에너지  용산구
# 261          제이제이주유소           서울 강남구 언주로 716  2545.0  N  현대오일뱅크  강남구
# 33           제이제이주유소           서울 강남구 언주로 716  2545.0  N  현대오일뱅크  강남구
# 324            한석주유소           서울 용산구 이촌로 164  2531.0  N   SK에너지  용산구
# 357            필동주유소    서울 중구  퇴계로 196 (필동2가)  2519.0  N   GS칼텍스   중구
# 260         (주)만정에너지    서울 강남구 봉은사로 433 (삼성동)  2498.0  N   GS칼텍스  강남구
# 32          (주)만정에너지    서울 강남구 봉은사로 433 (삼성동)  2498.0  N   GS칼텍스  강남구
# 356            약수주유소            서울 중구 다산로 173  2483.0  N   GS칼텍스   중구
#
#            lat         lng
# 359  37.558348  126.972090
# 358  37.561648  126.997142
# 325  37.550179  126.972463
# 261  37.517636  127.035756
# 33   37.517636  127.035756
# 324  37.521421  126.965379
# 357  37.560850  126.993653
# 260  37.511513  127.047093
# 32   37.511513  127.047093
# 356  37.559009  127.012663

# %%
lat = []
lng = []

for n in tqdm(oil_price_bottom10.index):
    try:
        tmp_add = oil_price_bottom10['주소'][n].split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0]['geometry']
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
    
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 11.79it/s]
#           Oil_store                         주소      가격 셀프     상표    구  \
# 34            한신주유소      서울 노원구 동일로 1089 (공릉동)  1968.0  Y  SK에너지  노원구
# 196          아시아주유소       서울 송파구 도곡로 438 (잠실동)  1978.0  Y  GS칼텍스  송파구
# 122          신반포주유소       서울 서초구 사평대로 94 (반포동)  1978.0  N  SK에너지  서초구
# 264           현대주유소     서울 양천구 남부순환로 372 (신월동)  1979.0  Y  S-OIL  양천구
# 262           신월주유소       서울 양천구 신월로 193 (신월동)  1979.0  Y  GS칼텍스  양천구
# 263  (주)타이거오일 신정주유소       서울 양천구 중앙로 226 (신정동)  1979.0  Y  SK에너지  양천구
# 265   지에스칼텍스㈜ 서호주유소           서울 양천구 남부순환로 317  1980.0  Y  GS칼텍스  양천구
# 401           방화주유소     서울 강서구 방화동로 58-2 (방화동)  1983.0  N  SK에너지  강서구
# 266          양천구주유소       서울 양천구 국회대로 275 (목동)  1985.0  Y  알뜰주유소  양천구
# 483           구광주유소  서울특별시 금천구  서부샛길 674 (가산동)  1985.0  N  S-OIL  금천구
#
#            lat         lng
# 34   37.626905  127.071896
# 196  37.504572  127.077380
# 122  37.498326  126.994934
# 264  37.533811  126.829240
# 262  37.520014  126.844069
# 263  37.516768  126.854657
# 265  37.538552  126.826928
# 401  37.565571  126.812387
# 266  37.530283  126.865529
# 483  37.481968  126.875149

# %%
map = folium.Map(location=[37.5202, 126.975], zoom_start=10.5)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]], 
                                  radius=15, color='#CD3181', 
                                  fill_color='#CD3181',
                                  fill=True).add_to(map)
    
for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]): 
        folium.CircleMarker([oil_price_bottom10['lat'][n], 
                                  oil_price_bottom10['lng'][n]], 
                                  radius=15, color='#3186cc', 
                                  fill_color='#3186cc',
                                  fill=True).add_to(map)
        
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_99f297cf60bd4c53a9cccdaa9efb2611%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_99f297cf60bd4c53a9cccdaa9efb2611%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_99f297cf60bd4c53a9cccdaa9efb2611%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_99f297cf60bd4c53a9cccdaa9efb2611%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5202%2C%20126.975%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
